# %%
import pandas as pd
import geopandas as gpd

# %% [markdown]
# Election Results

# %%
df_2018 = pd.read_csv('../data/Nov 2018 General results.csv')
df_2018
# Out:
#          COUNTY  PRCTSEQ       PRECINCT  BALSEQID  JURISID SECJURISID  \
# 0      Anderson        1  Andersonville         5        0          0
# 1      Anderson        1  Andersonville         5        0          0
# 2      Anderson        1  Andersonville         5        0          0
# 3      Anderson        1  Andersonville         7        0          0
# 4      Anderson        1  Andersonville        11        3          0
# ...         ...      ...            ...       ...      ...        ...
# 13237    Wilson       33    Provisional         7        0          0
# 13238    Wilson       33    Provisional        11        6          0
# 13239    Wilson       33    Provisional        15       17          0
# 13240    Wilson       33    Provisional        17       46          0
# 13241    Wilson       33    Provisional        17       57          0
#
#        CANDGROUP                                         OFFICENAME  \
# ...

# %%
df_2022 = pd.read_csv('../data/Nov 2022 All results.csv')
df_2022
# Out:
#            COUNTY  PRCTSEQ          PRECINCT  BALSEQID  JURISID  SECJURISID  \
# 0      Lauderdale        1         Henning 1         5        0           0
# 1      Lauderdale        1         Henning 1         5        0           0
# 2      Lauderdale        1         Henning 1         6        0           1
# 3      Lauderdale        1         Henning 1         6        0           2
# 4      Lauderdale        1         Henning 1         6        0           3
# ...           ...      ...               ...       ...      ...         ...
# 16180   Humphreys        8  7-8 North McEwen         6        0           4
# 16181   Humphreys        8  7-8 North McEwen        11        7           0
# 16182   Humphreys        8  7-8 North McEwen        15       23           0
# 16183   Humphreys        8  7-8 North McEwen        17       74           0
# 16184   Van Buren        1         Spencer 1        17       31           0
#
# ...

# %%
df_2018.shape
df_2022.shape
# Out:
# (16185, 50)

# %%
df_2018.columns
# Out:
# Index(['COUNTY', 'PRCTSEQ', 'PRECINCT', 'BALSEQID', 'JURISID', 'SECJURISID',
#        'CANDGROUP', 'OFFICENAME', 'ELECTDATE', 'ELECTTYPE', 'COL1HDG',
#        'RNAME1', 'PARTY1', 'PVTALLY1', 'COL2HDG', 'RNAME2', 'PARTY2',
#        'PVTALLY2', 'COL3HDG', 'RNAME3', 'PARTY3', 'PVTALLY3', 'COL4HDG',
#        'RNAME4', 'PARTY4', 'PVTALLY4', 'COL5HDG', 'RNAME5', 'PARTY5',
#        'PVTALLY5', 'COL6HDG', 'RNAME6', 'PARTY6', 'PVTALLY6', 'COL7HDG',
#        'RNAME7', 'PARTY7', 'PVTALLY7', 'COL8HDG', 'RNAME8', 'PARTY8',
#        'PVTALLY8', 'COL9HDG', 'RNAME9', 'PARTY9', 'PVTALLY9', 'COL10HDG',
#        'RNAME10', 'PARTY10', 'PVTALLY10'],
#       dtype='object')

# %%
df_2022.columns
# Out:
# Index(['COUNTY', 'PRCTSEQ', 'PRECINCT', 'BALSEQID', 'JURISID', 'SECJURISID',
#        'CANDGROUP', 'OFFICENAME', 'ELECTDATE', 'ELECTTYPE', 'COL1HDG',
#        'RNAME1', 'PARTY1', 'PVTALLY1', 'COL2HDG', 'RNAME2', 'PARTY2',
#        'PVTALLY2', 'COL3HDG', 'RNAME3', 'PARTY3', 'PVTALLY3', 'COL4HDG',
#        'RNAME4', 'PARTY4', 'PVTALLY4', 'COL5HDG', 'RNAME5', 'PARTY5',
#        'PVTALLY5', 'COL6HDG', 'RNAME6', 'PARTY6', 'PVTALLY6', 'COL7HDG',
#        'RNAME7', 'PARTY7', 'PVTALLY7', 'COL8HDG', 'RNAME8', 'PARTY8',
#        'PVTALLY8', 'COL9HDG', 'RNAME9', 'PARTY9', 'PVTALLY9', 'COL10HDG',
#        'RNAME10', 'PARTY10', 'PVTALLY10'],
#       dtype='object')

# %%
df_2018["OFFICENAME"].value_counts()
# Out:
# OFFICENAME
# Governor                                             5964
# United States Senate                                 1988
# United States House of Representatives District 3     294
# United States House of Representatives District 7     281
# United States House of Representatives District 6     266
#                                                      ...
# Tennessee House of Representatives District 24         10
# Tennessee House of Representatives District 2          10
# Tennessee House of Representatives District 14         10
# Tennessee House of Representatives District 18         10
# Tennessee House of Representatives District 81          9
# Name: count, Length: 128, dtype: int64

# %%
df_2022["OFFICENAME"].value_counts()
# Out:
# OFFICENAME
# Governor                                          3702
# Constitutional Amendment # 2                      1850
# Constitutional Amendment # 3                      1850
# Constitutional Amendment # 4                      1850
# Constitutional Amendment # 1                      1850
#                                                   ...
# Tennessee House of Representatives District 49      10
# Tennessee House of Representatives District 61      10
# Tennessee House of Representatives District 13      10
# Tennessee House of Representatives District 24      10
# Tennessee House of Representatives District 63       7
# Name: count, Length: 130, dtype: int64

# %%
gov_2018 = df_2018[df_2018["OFFICENAME"] == "Governor"].copy()
gov_2018
# Out:
#          COUNTY  PRCTSEQ       PRECINCT  BALSEQID  JURISID SECJURISID  \
# 0      Anderson        1  Andersonville         5        0          0
# 1      Anderson        1  Andersonville         5        0          0
# 2      Anderson        1  Andersonville         5        0          0
# 7      Anderson        2     Briceville         5        0          0
# 8      Anderson        2     Briceville         5        0          0
# ...         ...      ...            ...       ...      ...        ...
# 13227    Wilson       32       Absentee         5        0          0
# 13228    Wilson       32       Absentee         5        0          0
# 13234    Wilson       33    Provisional         5        0          0
# 13235    Wilson       33    Provisional         5        0          0
# 13236    Wilson       33    Provisional         5        0          0
#
#        CANDGROUP OFFICENAME   ELECTDATE      ELECTTYPE  ...       PARTY8  \
# ...

# %%
gov_2022 = df_2022[df_2022["OFFICENAME"] == "Governor"].copy()
gov_2022
# Out:
#            COUNTY  PRCTSEQ          PRECINCT  BALSEQID  JURISID  SECJURISID  \
# 0      Lauderdale        1         Henning 1         5        0           0
# 1      Lauderdale        1         Henning 1         5        0           0
# 8         Johnson        1         1A Laurel         5        0           0
# 9         Johnson        1         1A Laurel         5        0           0
# 17        Johnson        2   1B Cold Springs         5        0           0
# ...           ...      ...               ...       ...      ...         ...
# 16158   Humphreys        6      5-6 Wildwood         5        0           0
# 16166   Humphreys        7  6-7 South McEwen         5        0           0
# 16167   Humphreys        7  6-7 South McEwen         5        0           0
# 16175   Humphreys        8  7-8 North McEwen         5        0           0
# 16176   Humphreys        8  7-8 North McEwen         5        0           0
#
# ...

# %%
vote_cols = [col for col in gov_2018.columns if col.startswith("PVTALLY")]
vote_cols
# Out:
# ['PVTALLY1',
#  'PVTALLY2',
#  'PVTALLY3',
#  'PVTALLY4',
#  'PVTALLY5',
#  'PVTALLY6',
#  'PVTALLY7',
#  'PVTALLY8',
#  'PVTALLY9',
#  'PVTALLY10']

# %%
vcols = ([col for col in gov_2022.columns if col.startswith("PVTALLY")])
vcols
# Out:
# ['PVTALLY1',
#  'PVTALLY2',
#  'PVTALLY3',
#  'PVTALLY4',
#  'PVTALLY5',
#  'PVTALLY6',
#  'PVTALLY7',
#  'PVTALLY8',
#  'PVTALLY9',
#  'PVTALLY10']

# %%
gov_2018[vote_cols].isna().sum()
# Out:
# PVTALLY1        0
# PVTALLY2        0
# PVTALLY3        0
# PVTALLY4        0
# PVTALLY5        0
# PVTALLY6        0
# PVTALLY7        0
# PVTALLY8        0
# PVTALLY9        0
# PVTALLY10    1988
# dtype: int64

# %%
gov_2022[vote_cols].isna().sum()
# Out:
# PVTALLY1        0
# PVTALLY2        0
# PVTALLY3        0
# PVTALLY4        0
# PVTALLY5     1835
# PVTALLY6     1835
# PVTALLY7     1835
# PVTALLY8     1835
# PVTALLY9     1835
# PVTALLY10    1835
# dtype: int64

# %%
gov_2018["total_votes"] = gov_2018[vote_cols].sum(axis=1)

# %%
gov_2022["total_votes"] = gov_2022[vote_cols].sum(axis=1)

# %%
gov_2018["total_votes"].describe()
# Out:
# count     5964.000000
# mean       376.139168
# std        927.147541
# min          0.000000
# 25%          2.000000
# 50%          6.000000
# 75%        450.250000
# max      46331.000000
# Name: total_votes, dtype: float64

# %%
gov_2022["total_votes"].describe()
# Out:
# count    3702.000000
# mean      469.984333
# std       717.971346
# min         0.000000
# 25%         0.000000
# 50%         4.000000
# 75%       723.750000
# max      7794.000000
# Name: total_votes, dtype: float64

# %%
gov_2018[["COUNTY", "PRECINCT"]].head(10)
# Out:
#       COUNTY       PRECINCT
# 0   Anderson  Andersonville
# 1   Anderson  Andersonville
# 2   Anderson  Andersonville
# 7   Anderson     Briceville
# 8   Anderson     Briceville
# 9   Anderson     Briceville
# 14  Anderson       Bull Run
# 15  Anderson       Bull Run
# 16  Anderson       Bull Run
# 21  Anderson        Clinton

# %%
gov_2022[["COUNTY", "PRECINCT"]].head(10)
# Out:
#         COUNTY         PRECINCT
# 0   Lauderdale        Henning 1
# 1   Lauderdale        Henning 1
# 8      Johnson        1A Laurel
# 9      Johnson        1A Laurel
# 17     Johnson  1B Cold Springs
# 18     Johnson  1B Cold Springs
# 26     Johnson   2 Forge/Shouns
# 27     Johnson   2 Forge/Shouns
# 35     Johnson         3A Trade
# 36     Johnson         3A Trade

# %%
for df in [gov_2018, gov_2022]:
    df["COUNTY"] = df["COUNTY"].str.upper().str.strip()
    df["PRECINCT"] = df["PRECINCT"].str.upper().str.strip()

# %%
gov_2018["COUNTY"].nunique()
# Out:
# 95

# %%
gov_2022["COUNTY"].nunique()
# Out:
# 95

# %% [markdown]
# Voter Turnout by County

# %%
county_2018 = (gov_2018.groupby("COUNTY", as_index=False)["total_votes"].sum())
county_2018["year"] = 2018
county_2018
# Out:
#         COUNTY  total_votes  year
# 0     ANDERSON      26040.0  2018
# 1      BEDFORD      13049.0  2018
# 2       BENTON       5346.0  2018
# 3      BLEDSOE       4072.0  2018
# 4       BLOUNT      46775.0  2018
# ..         ...          ...   ...
# 90       WAYNE       4731.0  2018
# 91     WEAKLEY       9892.0  2018
# 92       WHITE       8444.0  2018
# 93  WILLIAMSON     105654.0  2018
# 94      WILSON      53067.0  2018
#
# [95 rows x 3 columns]

# %%
county_2022 = (gov_2022.groupby("COUNTY", as_index=False)["total_votes"].sum())
county_2022["year"] = 2022
county_2022
# Out:
#         COUNTY  total_votes  year
# 0     ANDERSON      21280.0  2022
# 1      BEDFORD      10594.0  2022
# 2       BENTON       4103.0  2022
# 3      BLEDSOE       3408.0  2022
# 4       BLOUNT      39606.0  2022
# ..         ...          ...   ...
# 90       WAYNE       3573.0  2022
# 91     WEAKLEY       8129.0  2022
# 92       WHITE       6970.0  2022
# 93  WILLIAMSON      85417.0  2022
# 94      WILSON      44552.0  2022
#
# [95 rows x 3 columns]

# %% [markdown]
# Governor Votes by Party and County

# %%
party_vote_pairs = [(f"PARTY{i}", f"PVTALLY{i}") for i in range(1, 11)]
party_vote_pairs
# Out:
# [('PARTY1', 'PVTALLY1'),
#  ('PARTY2', 'PVTALLY2'),
#  ('PARTY3', 'PVTALLY3'),
#  ('PARTY4', 'PVTALLY4'),
#  ('PARTY5', 'PVTALLY5'),
#  ('PARTY6', 'PVTALLY6'),
#  ('PARTY7', 'PVTALLY7'),
#  ('PARTY8', 'PVTALLY8'),
#  ('PARTY9', 'PVTALLY9'),
#  ('PARTY10', 'PVTALLY10')]

# %%
def reshape_party_votes(df, year):
    rows = []
    
    for party_col, vote_col in party_vote_pairs:
        subset = df[["COUNTY", party_col, vote_col]].copy()
        subset = subset.dropna(subset=[vote_col])
        subset = subset.rename(columns={party_col: "party", vote_col: "votes"})
        subset["year"] = year
        rows.append(subset)

    return pd.concat(rows, ignore_index=True)

# %%
party_2018 = reshape_party_votes(gov_2018, 2018)
party_2018
# Out:
#          COUNTY        party   votes  year
# 0      ANDERSON   Republican  1011.0  2018
# 1      ANDERSON  Independent     0.0  2018
# 2      ANDERSON  Independent     0.0  2018
# 3      ANDERSON   Republican   181.0  2018
# 4      ANDERSON  Independent     0.0  2018
# ...         ...          ...     ...   ...
# 57647    WILSON  Independent     0.0  2018
# 57648    WILSON  Independent     0.0  2018
# 57649    WILSON  Independent     0.0  2018
# 57650    WILSON  Independent     0.0  2018
# 57651    WILSON  Independent     0.0  2018
#
# [57652 rows x 4 columns]

# %%
party_2022 = reshape_party_votes(gov_2022, 2022)
party_2022
# Out:
#            COUNTY        party  votes  year
# 0      LAUDERDALE   Republican  174.0  2022
# 1      LAUDERDALE          NaN    0.0  2022
# 2         JOHNSON   Republican  481.0  2022
# 3         JOHNSON          NaN    0.0  2022
# 4         JOHNSON   Republican  453.0  2022
# ...           ...          ...    ...   ...
# 26005   HUMPHREYS  Independent    0.0  2022
# 26006   HUMPHREYS  Independent    1.0  2022
# 26007   HUMPHREYS  Independent    0.0  2022
# 26008   HUMPHREYS  Independent    0.0  2022
# 26009   HUMPHREYS  Independent    0.0  2022
#
# [26010 rows x 4 columns]

# %%
for df in [party_2018, party_2022]:
    df["party"] = df["party"].str.upper().str.strip()

# %%
county_party_2018 = (party_2018.groupby(["COUNTY", "party", "year"], as_index=False)["votes"].sum())
county_party_2018
# Out:
#          COUNTY        party  year    votes
# 0      ANDERSON   DEMOCRATIC  2018   9462.0
# 1      ANDERSON  INDEPENDENT  2018    313.0
# 2      ANDERSON   REPUBLICAN  2018  16265.0
# 3       BEDFORD   DEMOCRATIC  2018   3447.0
# 4       BEDFORD  INDEPENDENT  2018    113.0
# ..          ...          ...   ...      ...
# 280  WILLIAMSON  INDEPENDENT  2018   2816.0
# 281  WILLIAMSON   REPUBLICAN  2018  68189.0
# 282      WILSON   DEMOCRATIC  2018  16987.0
# 283      WILSON  INDEPENDENT  2018    592.0
# 284      WILSON   REPUBLICAN  2018  35488.0
#
# [285 rows x 4 columns]

# %%
county_party_2022 = (party_2022.groupby(["COUNTY", "party", "year"], as_index=False)["votes"].sum())
county_party_2022
# Out:
#          COUNTY        party  year    votes
# 0      ANDERSON   DEMOCRATIC  2022   6832.0
# 1      ANDERSON  INDEPENDENT  2022    440.0
# 2      ANDERSON   REPUBLICAN  2022  14003.0
# 3       BEDFORD   DEMOCRATIC  2022   1936.0
# 4       BEDFORD  INDEPENDENT  2022    256.0
# ..          ...          ...   ...      ...
# 280  WILLIAMSON  INDEPENDENT  2022   1153.0
# 281  WILLIAMSON   REPUBLICAN  2022  58132.0
# 282      WILSON   DEMOCRATIC  2022  12208.0
# 283      WILSON  INDEPENDENT  2022    833.0
# 284      WILSON   REPUBLICAN  2022  31496.0
#
# [285 rows x 4 columns]

# %%
county_party_2018["party"].value_counts()
# Out:
# party
# DEMOCRATIC     95
# INDEPENDENT    95
# REPUBLICAN     95
# Name: count, dtype: int64

# %%
county_party_2022["party"].value_counts()
# Out:
# party
# DEMOCRATIC     95
# INDEPENDENT    95
# REPUBLICAN     95
# Name: count, dtype: int64

# %%
county_party_all = pd.concat([county_party_2018, county_party_2022],ignore_index=True)
county_party_all
# Out:
#          COUNTY        party  year    votes
# 0      ANDERSON   DEMOCRATIC  2018   9462.0
# 1      ANDERSON  INDEPENDENT  2018    313.0
# 2      ANDERSON   REPUBLICAN  2018  16265.0
# 3       BEDFORD   DEMOCRATIC  2018   3447.0
# 4       BEDFORD  INDEPENDENT  2018    113.0
# ..          ...          ...   ...      ...
# 565  WILLIAMSON  INDEPENDENT  2022   1153.0
# 566  WILLIAMSON   REPUBLICAN  2022  58132.0
# 567      WILSON   DEMOCRATIC  2022  12208.0
# 568      WILSON  INDEPENDENT  2022    833.0
# 569      WILSON   REPUBLICAN  2022  31496.0
#
# [570 rows x 4 columns]

# %%
county_totals = (county_party_all.groupby(["COUNTY", "year"], as_index=False)["votes"].sum().rename(columns={"votes": "total_votes"}))

# %% [markdown]
# County Vote Distribution

# %%
county_party_all = county_party_all.merge(county_totals, on=["COUNTY", "year"], how="left")
county_party_all
# Out:
#          COUNTY        party  year    votes  total_votes
# 0      ANDERSON   DEMOCRATIC  2018   9462.0      26040.0
# 1      ANDERSON  INDEPENDENT  2018    313.0      26040.0
# 2      ANDERSON   REPUBLICAN  2018  16265.0      26040.0
# 3       BEDFORD   DEMOCRATIC  2018   3447.0      13049.0
# 4       BEDFORD  INDEPENDENT  2018    113.0      13049.0
# ..          ...          ...   ...      ...          ...
# 565  WILLIAMSON  INDEPENDENT  2022   1153.0      85401.0
# 566  WILLIAMSON   REPUBLICAN  2022  58132.0      85401.0
# 567      WILSON   DEMOCRATIC  2022  12208.0      44537.0
# 568      WILSON  INDEPENDENT  2022    833.0      44537.0
# 569      WILSON   REPUBLICAN  2022  31496.0      44537.0
#
# [570 rows x 5 columns]

# %%
county_party_all["vote_share"] = (county_party_all["votes"] / county_party_all["total_votes"])
county_party_all
# Out:
#          COUNTY        party  year    votes  total_votes  vote_share
# 0      ANDERSON   DEMOCRATIC  2018   9462.0      26040.0    0.363364
# 1      ANDERSON  INDEPENDENT  2018    313.0      26040.0    0.012020
# 2      ANDERSON   REPUBLICAN  2018  16265.0      26040.0    0.624616
# 3       BEDFORD   DEMOCRATIC  2018   3447.0      13049.0    0.264158
# 4       BEDFORD  INDEPENDENT  2018    113.0      13049.0    0.008660
# ..          ...          ...   ...      ...          ...         ...
# 565  WILLIAMSON  INDEPENDENT  2022   1153.0      85401.0    0.013501
# 566  WILLIAMSON   REPUBLICAN  2022  58132.0      85401.0    0.680695
# 567      WILSON   DEMOCRATIC  2022  12208.0      44537.0    0.274109
# 568      WILSON  INDEPENDENT  2022    833.0      44537.0    0.018704
# 569      WILSON   REPUBLICAN  2022  31496.0      44537.0    0.707187
#
# [570 rows x 6 columns]

# %%
county_party_sorted = county_party_all.sort_values(["COUNTY", "year", "votes"],ascending=[True, True, False])

# %%
top_two = (county_party_sorted.groupby(["COUNTY", "year"]).head(2))
top_two
# Out:
#          COUNTY       party  year    votes  total_votes  vote_share
# 2      ANDERSON  REPUBLICAN  2018  16265.0      26040.0    0.624616
# 0      ANDERSON  DEMOCRATIC  2018   9462.0      26040.0    0.363364
# 287    ANDERSON  REPUBLICAN  2022  14003.0      21275.0    0.658190
# 285    ANDERSON  DEMOCRATIC  2022   6832.0      21275.0    0.321128
# 5       BEDFORD  REPUBLICAN  2018   9489.0      13049.0    0.727182
# ..          ...         ...   ...      ...          ...         ...
# 564  WILLIAMSON  DEMOCRATIC  2022  26116.0      85401.0    0.305804
# 284      WILSON  REPUBLICAN  2018  35488.0      53067.0    0.668740
# 282      WILSON  DEMOCRATIC  2018  16987.0      53067.0    0.320105
# 569      WILSON  REPUBLICAN  2022  31496.0      44537.0    0.707187
# 567      WILSON  DEMOCRATIC  2022  12208.0      44537.0    0.274109
#
# [380 rows x 6 columns]

# %% [markdown]
# Win Margin

# %%
margin = (top_two.groupby(["COUNTY", "year"]).apply(lambda x: x.iloc[0]["votes"] - x.iloc[1]["votes"]).reset_index(name="margin_votes"))
margin
# Out:
# C:\Users\kanak\AppData\Local\Temp\ipykernel_9068\878679697.py:1: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   margin = (top_two.groupby(["COUNTY", "year"]).apply(lambda x: x.iloc[0]["votes"] - x.iloc[1]["votes"]).reset_index(name="margin_votes"))
#          COUNTY  year  margin_votes
# 0      ANDERSON  2018        6803.0
# 1      ANDERSON  2022        7171.0
# 2       BEDFORD  2018        6042.0
# 3       BEDFORD  2022        6465.0
# 4        BENTON  2018        2097.0
# ..          ...   ...           ...
# 185       WHITE  2022        4669.0
# 186  WILLIAMSON  2018       33542.0
# 187  WILLIAMSON  2022       32016.0
# 188      WILSON  2018       18501.0
# 189      WILSON  2022       19288.0
#
# ...

# %%
winners = (top_two.groupby(["COUNTY", "year"]).first().reset_index()[["COUNTY", "year", "party"]].rename(columns={"party": "winning_party"}))
winners
# Out:
#          COUNTY  year winning_party
# 0      ANDERSON  2018    REPUBLICAN
# 1      ANDERSON  2022    REPUBLICAN
# 2       BEDFORD  2018    REPUBLICAN
# 3       BEDFORD  2022    REPUBLICAN
# 4        BENTON  2018    REPUBLICAN
# ..          ...   ...           ...
# 185       WHITE  2022    REPUBLICAN
# 186  WILLIAMSON  2018    REPUBLICAN
# 187  WILLIAMSON  2022    REPUBLICAN
# 188      WILSON  2018    REPUBLICAN
# 189      WILSON  2022    REPUBLICAN
#
# [190 rows x 3 columns]

# %%
county_results = (winners.merge(margin, on=["COUNTY", "year"]).merge(county_totals, on=["COUNTY", "year"]))
county_results
# Out:
#          COUNTY  year winning_party  margin_votes  total_votes
# 0      ANDERSON  2018    REPUBLICAN        6803.0      26040.0
# 1      ANDERSON  2022    REPUBLICAN        7171.0      21275.0
# 2       BEDFORD  2018    REPUBLICAN        6042.0      13049.0
# 3       BEDFORD  2022    REPUBLICAN        6465.0      10593.0
# 4        BENTON  2018    REPUBLICAN        2097.0       5346.0
# ..          ...   ...           ...           ...          ...
# 185       WHITE  2022    REPUBLICAN        4669.0       6970.0
# 186  WILLIAMSON  2018    REPUBLICAN       33542.0     105652.0
# 187  WILLIAMSON  2022    REPUBLICAN       32016.0      85401.0
# 188      WILSON  2018    REPUBLICAN       18501.0      53067.0
# 189      WILSON  2022    REPUBLICAN       19288.0      44537.0
#
# [190 rows x 5 columns]

# %% [markdown]
# Geospatial

# %%
cd_2018 = gpd.read_file("../data/2018_us_county_within_cd.zip")
cd_2018
# Out:
#      STATEFP COUNTYFP CD116FP          AFFGEOID    GEOID PARTFLG       ALAND  \
# 0         31      007      03  5101600US3103007  3103007       N  1932676689
# 1         22      057      01  5101600US2201057  2201057       Y  1943718627
# 2         22      071      01  5101600US2201071  2201071       Y    27736769
# 3         22      103      01  5101600US2201103  2201103       N  2191719306
# 4         22      053      03  5101600US2203053  2203053       N  1687025357
# ...      ...      ...     ...               ...      ...     ...         ...
# 3832      01      081      03  5101600US0103081  0103081       N  1573548952
# 3833      37      181      01  5101600US3701181  3701181       N   653708021
# 3834      55      103      03  5101600US5503103  5503103       Y  1313273316
# 3835      22      007      02  5101600US2202007  2202007       Y   278235174
# 3836      18      127      01  5101600US1801127  1801127       N  1082793402
#
# ...

# %%
cd_2022 = gpd.read_file("../data/2022_us_county_within_cd.zip")
cd_2022
# Out:
#      STATEFP COUNTYFP CD118FP           GEOIDFQ    GEOID PARTFLG        ALAND  \
# 0         48      067      01  5101800US4801067  4801067       N   2426683491
# 1         08      019      02  5101800US0802019  0802019       N   1023234059
# 2         48      387      01  5101800US4801387  4801387       Y   1316355507
# 3         16      059      02  5101800US1602059  1602059       N  11819914567
# 4         06      027      03  5101800US0603027  0603027       N  26410783053
# ...      ...      ...     ...               ...      ...     ...          ...
# 3836      25      023      04  5101800US2504023  2504023       Y     76656455
# 3837      25      017      06  5101800US2506017  2506017       Y    265056576
# 3838      35      028      03  5101800US3503028  3503028       N    282626748
# 3839      39      031      12  5101800US3912031  3912031       N   1460521589
# 3840      39      071      02  5101800US3902071  3902071       N   1432479979
#
# ...

# %%
tn_2018 = cd_2018[cd_2018["STATEFP"] == "47"].copy()
tn_2018
# Out:
#      STATEFP COUNTYFP CD116FP          AFFGEOID    GEOID PARTFLG       ALAND  \
# 269       47      129      03  5101600US4703129  4703129       N  1352439680
# 270       47      013      03  5101600US4703013  4703013       Y  1005831327
# 271       47      065      03  5101600US4703065  4703065       N  1404654388
# 272       47      145      03  5101600US4703145  4703145       N   934286859
# 273       47      151      03  5101600US4703151  4703151       N  1378652161
# ...      ...      ...     ...               ...      ...     ...         ...
# 3639      47      137      06  5101600US4706137  4706137       N   422113134
# 3720      47      153      04  5101600US4704153  4704153       N   688550851
# 3721      47      007      04  5101600US4704007  4704007       N  1052635795
# 3770      47      061      04  5101600US4704061  4704061       N   933548206
# 3812      47      075      08  5101600US4708075  4708075       N  1380741546
#
# ...

# %%
tn_2022 = cd_2022[cd_2022["STATEFP"] == "47"].copy()
tn_2022
# Out:
#      STATEFP COUNTYFP CD118FP           GEOIDFQ    GEOID PARTFLG       ALAND  \
# 689       47      063      01  5101800US4701063  4701063       N   417476191
# 690       47      163      01  5101800US4701163  4701163       N  1071072985
# 691       47      089      01  5101800US4701089  4701089       Y   691612996
# 692       47      173      02  5101800US4702173  4702173       N   579077904
# 693       47      057      02  5101800US4702057  4702057       N   726715759
# ...      ...      ...     ...               ...      ...     ...         ...
# 3398      47      009      02  5101800US4702009  4702009       N  1447336789
# 3399      47      013      03  5101800US4703013  4703013       Y   381761184
# 3400      47      003      04  5101800US4704003  4704003       N  1226719752
# 3410      47      103      04  5101800US4704103  4704103       N  1477179214
# 3411      47      099      04  5101800US4704099  4704099       N  1598359119
#
# ...

# %%
tn_2018["area"] = tn_2018.geometry.area
tn_2018
# Out:
# C:\Users\kanak\AppData\Local\Temp\ipykernel_9068\1913858409.py:1: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   tn_2018["area"] = tn_2018.geometry.area
#      STATEFP COUNTYFP CD116FP          AFFGEOID    GEOID PARTFLG       ALAND  \
# 269       47      129      03  5101600US4703129  4703129       N  1352439680
# 270       47      013      03  5101600US4703013  4703013       Y  1005831327
# 271       47      065      03  5101600US4703065  4703065       N  1404654388
# 272       47      145      03  5101600US4703145  4703145       N   934286859
# 273       47      151      03  5101600US4703151  4703151       N  1378652161
# ...      ...      ...     ...               ...      ...     ...         ...
# 3639      47      137      06  5101600US4706137  4706137       N   422113134
# ...

# %%
tn_2022["area"] = tn_2022.geometry.area
tn_2022
# Out:
# C:\Users\kanak\AppData\Local\Temp\ipykernel_9068\925680929.py:1: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   tn_2022["area"] = tn_2022.geometry.area
#      STATEFP COUNTYFP CD118FP           GEOIDFQ    GEOID PARTFLG       ALAND  \
# 689       47      063      01  5101800US4701063  4701063       N   417476191
# 690       47      163      01  5101800US4701163  4701163       N  1071072985
# 691       47      089      01  5101800US4701089  4701089       Y   691612996
# 692       47      173      02  5101800US4702173  4702173       N   579077904
# 693       47      057      02  5101800US4702057  4702057       N   726715759
# ...      ...      ...     ...               ...      ...     ...         ...
# 3398      47      009      02  5101800US4702009  4702009       N  1447336789
# ...

# %%
tn_2022.columns
# Out:
# Index(['STATEFP', 'COUNTYFP', 'CD118FP', 'GEOIDFQ', 'GEOID', 'PARTFLG',
#        'ALAND', 'AWATER', 'geometry', 'area'],
#       dtype='object')

# %%
frag_2018 = (tn_2018.groupby(["STATEFP", "COUNTYFP"]).agg(districts_2018=("CD116FP", "nunique"),total_area_2018=("area", "sum") ).reset_index())
frag_2018
# Out:
#    STATEFP COUNTYFP  districts_2018  total_area_2018
# 0       47      001               1         0.089396
# 1       47      003               1         0.122179
# 2       47      005               2         0.113059
# 3       47      007               1         0.104770
# 4       47      009               1         0.146112
# ..     ...      ...             ...              ...
# 90      47      181               1         0.188672
# 91      47      183               1         0.151144
# 92      47      185               1         0.098131
# 93      47      187               1         0.150999
# 94      47      189               1         0.151347
#
# [95 rows x 4 columns]

# %%
frag_2022 = (tn_2022.groupby(["STATEFP", "COUNTYFP"]).agg(districts_2022=("CD118FP", "nunique"),total_area_2022=("area", "sum")).reset_index())
frag_2022
# Out:
#    STATEFP COUNTYFP  districts_2022  total_area_2022
# 0       47      001               1         0.089395
# 1       47      003               1         0.122178
# 2       47      005               2         0.113061
# 3       47      007               1         0.104809
# 4       47      009               1         0.146117
# ..     ...      ...             ...              ...
# 90      47      181               1         0.188672
# 91      47      183               1         0.151140
# 92      47      185               1         0.098132
# 93      47      187               2         0.150990
# 94      47      189               2         0.151121
#
# [95 rows x 4 columns]

# %%
frag_2018["districts_2018"].value_counts()
# Out:
# districts_2018
# 1    87
# 2     8
# Name: count, dtype: int64

# %%
frag_2022["districts_2022"].value_counts()
# Out:
# districts_2022
# 1    85
# 2     9
# 3     1
# Name: count, dtype: int64

# %%
fragmentation = frag_2018.merge(frag_2022, on=["STATEFP", "COUNTYFP"], how="outer")
fragmentation
# Out:
#    STATEFP COUNTYFP  districts_2018  total_area_2018  districts_2022  \
# 0       47      001               1         0.089396               1
# 1       47      003               1         0.122179               1
# 2       47      005               2         0.113059               2
# 3       47      007               1         0.104770               1
# 4       47      009               1         0.146112               1
# ..     ...      ...             ...              ...             ...
# 90      47      181               1         0.188672               1
# 91      47      183               1         0.151144               1
# 92      47      185               1         0.098131               1
# 93      47      187               1         0.150999               2
# 94      47      189               1         0.151347               2
#
#     total_area_2022
# 0          0.089395
# 1          0.122178
# 2          0.113061
# 3          0.104809
# 4          0.146117
# ...

# %%
fragmentation["delta_districts"] = (fragmentation["districts_2022"] - fragmentation["districts_2018"])
fragmentation
# Out:
#    STATEFP COUNTYFP  districts_2018  total_area_2018  districts_2022  \
# 0       47      001               1         0.089396               1
# 1       47      003               1         0.122179               1
# 2       47      005               2         0.113059               2
# 3       47      007               1         0.104770               1
# 4       47      009               1         0.146112               1
# ..     ...      ...             ...              ...             ...
# 90      47      181               1         0.188672               1
# 91      47      183               1         0.151144               1
# 92      47      185               1         0.098131               1
# 93      47      187               1         0.150999               2
# 94      47      189               1         0.151347               2
#
#     total_area_2022  delta_districts
# 0          0.089395                0
# 1          0.122178                0
# ...

# %%
# %pip install addfips
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import addfips

# %%
af = addfips.AddFIPS()

# %%
county_results["COUNTYFP"] = county_results["COUNTY"].apply(lambda x: af.get_county_fips(x, state="TN"))

# %%
county_results
# Out:
#          COUNTY  year winning_party  margin_votes  total_votes COUNTYFP
# 0      ANDERSON  2018    REPUBLICAN        6803.0      26040.0    47001
# 1      ANDERSON  2022    REPUBLICAN        7171.0      21275.0    47001
# 2       BEDFORD  2018    REPUBLICAN        6042.0      13049.0    47003
# 3       BEDFORD  2022    REPUBLICAN        6465.0      10593.0    47003
# 4        BENTON  2018    REPUBLICAN        2097.0       5346.0    47005
# ..          ...   ...           ...           ...          ...      ...
# 185       WHITE  2022    REPUBLICAN        4669.0       6970.0    47185
# 186  WILLIAMSON  2018    REPUBLICAN       33542.0     105652.0    47187
# 187  WILLIAMSON  2022    REPUBLICAN       32016.0      85401.0    47187
# 188      WILSON  2018    REPUBLICAN       18501.0      53067.0    47189
# 189      WILSON  2022    REPUBLICAN       19288.0      44537.0    47189
#
# [190 rows x 6 columns]

# %%
county_results[county_results["COUNTYFP"].isna()]["COUNTY"].unique()
# Out:
# array([], dtype=object)

# %%
county_results["COUNTYFP"] = county_results["COUNTYFP"].astype(str)
fragmentation["COUNTYFP"] = fragmentation["COUNTYFP"].astype(str)

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# Empty Congressional District Map

# %%
fig, axes = plt.subplots(1, 2, figsize=(14, 4))

districts_2018 = gpd.read_file("../data/2010_boundaries.json")
districts_2022 = gpd.read_file("../data/2020_boundaries.json")

districts_2018.plot(ax=axes[0], edgecolor="black", linewidth=0.6, facecolor="none")
axes[0].set_title("Congressional Districts Before Redistricting")
axes[0].axis("off")

districts_2022.plot(ax=axes[1],edgecolor="black",linewidth=0.6, facecolor="none")
axes[1].set_title("Congressional Districts After Redistricting")
axes[1].axis("off")

plt.tight_layout()

# %%
# %pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
fragmentation["delta_districts"].value_counts()
# Out:
# delta_districts
#  0    85
#  1     5
# -1     4
#  2     1
# Name: count, dtype: int64

# %%
fragmentation
# Out:
#    STATEFP COUNTYFP  districts_2018  total_area_2018  districts_2022  \
# 0       47      001               1         0.089396               1
# 1       47      003               1         0.122179               1
# 2       47      005               2         0.113059               2
# 3       47      007               1         0.104770               1
# 4       47      009               1         0.146112               1
# ..     ...      ...             ...              ...             ...
# 90      47      181               1         0.188672               1
# 91      47      183               1         0.151144               1
# 92      47      185               1         0.098131               1
# 93      47      187               1         0.150999               2
# 94      47      189               1         0.151347               2
#
#     total_area_2022  delta_districts
# 0          0.089395                0
# 1          0.122178                0
# ...

# %%
county_results
# Out:
#          COUNTY  year winning_party  margin_votes  total_votes COUNTYFP
# 0      ANDERSON  2018    REPUBLICAN        6803.0      26040.0    47001
# 1      ANDERSON  2022    REPUBLICAN        7171.0      21275.0    47001
# 2       BEDFORD  2018    REPUBLICAN        6042.0      13049.0    47003
# 3       BEDFORD  2022    REPUBLICAN        6465.0      10593.0    47003
# 4        BENTON  2018    REPUBLICAN        2097.0       5346.0    47005
# ..          ...   ...           ...           ...          ...      ...
# 185       WHITE  2022    REPUBLICAN        4669.0       6970.0    47185
# 186  WILLIAMSON  2018    REPUBLICAN       33542.0     105652.0    47187
# 187  WILLIAMSON  2022    REPUBLICAN       32016.0      85401.0    47187
# 188      WILSON  2018    REPUBLICAN       18501.0      53067.0    47189
# 189      WILSON  2022    REPUBLICAN       19288.0      44537.0    47189
#
# [190 rows x 6 columns]

# %%
county_results["COUNTYFP"] = (county_results["COUNTYFP"].astype(str).str[-3:].str.zfill(3))
county_results
# Out:
#          COUNTY  year winning_party  margin_votes  total_votes COUNTYFP
# 0      ANDERSON  2018    REPUBLICAN        6803.0      26040.0      001
# 1      ANDERSON  2022    REPUBLICAN        7171.0      21275.0      001
# 2       BEDFORD  2018    REPUBLICAN        6042.0      13049.0      003
# 3       BEDFORD  2022    REPUBLICAN        6465.0      10593.0      003
# 4        BENTON  2018    REPUBLICAN        2097.0       5346.0      005
# ..          ...   ...           ...           ...          ...      ...
# 185       WHITE  2022    REPUBLICAN        4669.0       6970.0      185
# 186  WILLIAMSON  2018    REPUBLICAN       33542.0     105652.0      187
# 187  WILLIAMSON  2022    REPUBLICAN       32016.0      85401.0      187
# 188      WILSON  2018    REPUBLICAN       18501.0      53067.0      189
# 189      WILSON  2022    REPUBLICAN       19288.0      44537.0      189
#
# [190 rows x 6 columns]

# %%
fragmentation["COUNTYFP"] = (fragmentation["COUNTYFP"].astype(str).str[-3:].str.zfill(3))
fragmentation
# Out:
#    STATEFP COUNTYFP  districts_2018  total_area_2018  districts_2022  \
# 0       47      001               1         0.089396               1
# 1       47      003               1         0.122179               1
# 2       47      005               2         0.113059               2
# 3       47      007               1         0.104770               1
# 4       47      009               1         0.146112               1
# ..     ...      ...             ...              ...             ...
# 90      47      181               1         0.188672               1
# 91      47      183               1         0.151144               1
# 92      47      185               1         0.098131               1
# 93      47      187               1         0.150999               2
# 94      47      189               1         0.151347               2
#
#     total_area_2022  delta_districts
# 0          0.089395                0
# 1          0.122178                0
# ...

# %%
analysis_df = county_results.merge(fragmentation, on="COUNTYFP", how="left")
analysis_df
# Out:
#          COUNTY  year winning_party  margin_votes  total_votes COUNTYFP  \
# 0      ANDERSON  2018    REPUBLICAN        6803.0      26040.0      001
# 1      ANDERSON  2022    REPUBLICAN        7171.0      21275.0      001
# 2       BEDFORD  2018    REPUBLICAN        6042.0      13049.0      003
# 3       BEDFORD  2022    REPUBLICAN        6465.0      10593.0      003
# 4        BENTON  2018    REPUBLICAN        2097.0       5346.0      005
# ..          ...   ...           ...           ...          ...      ...
# 185       WHITE  2022    REPUBLICAN        4669.0       6970.0      185
# 186  WILLIAMSON  2018    REPUBLICAN       33542.0     105652.0      187
# 187  WILLIAMSON  2022    REPUBLICAN       32016.0      85401.0      187
# 188      WILSON  2018    REPUBLICAN       18501.0      53067.0      189
# 189      WILSON  2022    REPUBLICAN       19288.0      44537.0      189
#
#     STATEFP  districts_2018  total_area_2018  districts_2022  total_area_2022  \
# ...

# %%
analysis_df["delta_districts"].describe()
# Out:
# count    190.000000
# mean       0.031579
# std        0.369545
# min       -1.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        2.000000
# Name: delta_districts, dtype: float64

# %%
import seaborn as sns

# %% [markdown]
# Scatterplot Fragmentation vs Voting Margin

# %%
sns.scatterplot(data=analysis_df.dropna(subset=["delta_districts", "margin_votes"]),x="delta_districts",y="margin_votes")
plt.xlabel("Change in Number of Districts per County")
plt.ylabel("Margin of Victory (Votes)")
plt.title("Redistricting Fragmentation vs Voting Margin")
# Out:
# Text(0.5, 1.0, 'Redistricting Fragmentation vs Voting Margin')

# %%
plt.figure(figsize=(8,6))
sns.scatterplot(data=analysis_df.dropna(subset=["delta_districts", "margin_votes"]),
    x="delta_districts",
    y="margin_votes",
    hue="winning_party",
    palette={"DEMOCRATIC": "#4C72B0","REPUBLICAN": "#C44E52"},
    alpha=0.65,
    edgecolor="white",
    linewidth=0.4)
plt.title("How Changes in District Boundaries Relate to Election Margins (2018–2022)")
plt.xlabel("Net Change in Congressional Districts Touching a County")
plt.ylabel("Change in Margin of Victory (Votes)")
plt.xticks(ticks=sorted(analysis_df["delta_districts"].dropna().unique()))
plt.axhline(0, linewidth=1, linestyle="--", alpha=0.6)
plt.legend(title="Winning Party (2022)")
plt.tight_layout()

# %% [markdown]
# Bar Chart Avg Turnout by Fragmentation

# %%
analysis_df["fragmented"] = analysis_df["delta_districts"] > 0
analysis_df.groupby("fragmented")["total_votes"].mean().plot(kind="bar", title="Average Turnout: Fragmented vs Non-Fragmented Counties")
# Out:
# <Axes: title={'center': 'Average Turnout: Fragmented vs Non-Fragmented Counties'}, xlabel='fragmented'>

# %%
analysis_df["fragmented"] = analysis_df["delta_districts"] > 0
avg_votes = (analysis_df.groupby("fragmented")["total_votes"].mean())

ax = avg_votes.plot(kind="bar",figsize=(6,5),color=["#A7B1C2", "#4C72B0"])

ax.set_title("Avg Total Votes Cast by Counties, Grouped by Boundary Change",fontsize=12)

ax.set_ylabel("Avg Total Votes Cast per County")
ax.set_xlabel("County Experienced Congressional Boundary Change (2018–2022)")

ax.set_xticklabels(["No Boundary Change", "Boundary Changed"],rotation=0)

for i, val in enumerate(avg_votes.values):
    ax.text(i, val, f"{int(val):,}", ha="center", va="bottom")

plt.tight_layout()

# %% [markdown]
# County Winning Party Map

# %%
counties_geom = (tn_2022.dissolve(by="COUNTYFP", as_index=False)[["COUNTYFP", "geometry"]])

# %%
vote_2022 = analysis_df[analysis_df["year"] == 2022]

# %%
map_df22 = counties_geom.merge(vote_2022,on="COUNTYFP",how="left")

# %%
fig, ax = plt.subplots(figsize=(8, 8))

map_df22.plot(column="winning_party",categorical=True,legend=True,ax=ax)
ax.set_title("Winning Party by County (2022 Governor Election)")
ax.axis("off")
# Out:
# (-90.74363065, -81.21372235, 34.8982147, 36.7628753)

# %%
party_colors = {"DEMOCRATIC": "#4C72B0",
                "REPUBLICAN": "#C38D8D"}

# %%
fig, ax = plt.subplots(figsize=(8, 6))

map_df22.plot(column="winning_party",
              categorical=True,
              legend=True,
              ax=ax,
              color=map_df22["winning_party"].map(party_colors),
              edgecolor="white",
              linewidth=0.3)

ax.set_title("County-Level Governor Election Outcome (2022)")
ax.axis("off")
# Out:
# C:\Users\kanak\anaconda3\envs\geospatial\lib\site-packages\geopandas\plotting.py:656: UserWarning: Only specify one of 'column' or 'color'. Using 'color'.
#   warnings.warn(
# (-90.74363065, -81.21372235, 34.8982147, 36.7628753)

# %%
from matplotlib.patches import Patch

fig, ax = plt.subplots(figsize=(8, 6))
map_df22.plot(ax=ax,
              color=map_df22["winning_party"].map(party_colors),
              edgecolor="white",
              linewidth=0.3)

legend_handles = [Patch(facecolor=party_colors["DEMOCRATIC"], edgecolor="none", label="DEMOCRATIC"),
                  Patch(facecolor=party_colors["REPUBLICAN"], edgecolor="none", label="REPUBLICAN")]

ax.legend(handles=legend_handles, title="Winning Party", loc="upper right")
ax.set_title("County-Level Governor Election Outcomes (2022)")
ax.axis("off")
plt.tight_layout()

# %%
counties_geom = (tn_2018.dissolve(by="COUNTYFP", as_index=False)[["COUNTYFP", "geometry"]])

# %%
vote_2018 = analysis_df[analysis_df["year"] == 2018]

# %%
map_df18 = counties_geom.merge(vote_2018,on="COUNTYFP",how="left")

# %%
fig, ax = plt.subplots(figsize=(8, 8))

map_df18.plot(column="winning_party",categorical=True,legend=True,ax=ax)
ax.set_title("Winning Party by County (2018 Governor Election)")
ax.axis("off")
# Out:
# (-90.74346789999998, -81.2137301, 34.8982147, 36.7628753)

# %%
fig, ax = plt.subplots(figsize=(8, 6))

map_df18.plot(
    column="winning_party",
    categorical=True,
    legend=True,
    ax=ax,
    color=map_df18["winning_party"].map(party_colors),
    edgecolor="white",
    linewidth=0.3
)

ax.set_title("County-Level Governor Election Outcomes (2018)")
ax.axis("off")
# Out:
# C:\Users\kanak\anaconda3\envs\geospatial\lib\site-packages\geopandas\plotting.py:656: UserWarning: Only specify one of 'column' or 'color'. Using 'color'.
#   warnings.warn(
# (-90.74346789999998, -81.2137301, 34.8982147, 36.7628753)

# %%
fig, ax = plt.subplots(figsize=(8, 6))
map_df18.plot(ax=ax,
              color=map_df18["winning_party"].map(party_colors),
              edgecolor="white",
              linewidth=0.3)

legend_handles = [Patch(facecolor=party_colors["DEMOCRATIC"], edgecolor="none", label="DEMOCRATIC"),
                  Patch(facecolor=party_colors["REPUBLICAN"], edgecolor="none", label="REPUBLICAN")]

ax.legend(handles=legend_handles, title="Winning Party", loc="upper right")
ax.set_title("County-Level Governor Election Outcomes (2018)")
ax.axis("off")
plt.tight_layout()

# %%
vote_wide = (analysis_df.pivot(index="COUNTYFP", columns="year", values=["total_votes", "margin_votes"]))

# %%
vote_wide.columns = [f"{metric}_{year}" for metric, year in vote_wide.columns]
vote_wide = vote_wide.reset_index()

# %%
vote_wide
# Out:
#    COUNTYFP  total_votes_2018  total_votes_2022  margin_votes_2018  \
# 0       001           26040.0           21275.0             6803.0
# 1       003           13049.0           10593.0             6042.0
# 2       005            5346.0            4100.0             2097.0
# 3       007            4072.0            3406.0             2179.0
# 4       009           46775.0           39595.0            19596.0
# ..      ...               ...               ...                ...
# 90      181            4731.0            3573.0             3058.0
# 91      183            9892.0            8129.0             4646.0
# 92      185            8444.0            6970.0             4369.0
# 93      187          105652.0           85401.0            33542.0
# 94      189           53067.0           44537.0            18501.0
#
#     margin_votes_2022
# 0              7171.0
# 1              6465.0
# 2              2491.0
# 3              2515.0
# 4             20154.0
# ...

# %%
vote_wide["delta_turnout"] = vote_wide["total_votes_2022"] - vote_wide["total_votes_2018"]
vote_wide["delta_margin"] = vote_wide["margin_votes_2022"] - vote_wide["margin_votes_2018"]
vote_wide
# Out:
#    COUNTYFP  total_votes_2018  total_votes_2022  margin_votes_2018  \
# 0       001           26040.0           21275.0             6803.0
# 1       003           13049.0           10593.0             6042.0
# 2       005            5346.0            4100.0             2097.0
# 3       007            4072.0            3406.0             2179.0
# 4       009           46775.0           39595.0            19596.0
# ..      ...               ...               ...                ...
# 90      181            4731.0            3573.0             3058.0
# 91      183            9892.0            8129.0             4646.0
# 92      185            8444.0            6970.0             4369.0
# 93      187          105652.0           85401.0            33542.0
# 94      189           53067.0           44537.0            18501.0
#
#     margin_votes_2022  delta_turnout  delta_margin
# 0              7171.0        -4765.0         368.0
# 1              6465.0        -2456.0         423.0
# ...

# %% [markdown]
# Distribution of Redistricting Impact - Bar

# %%
analysis_df["delta_districts"].value_counts().sort_index().plot(kind="bar")
plt.title("Distribution of Change in Congressional District Fragmentation by County")
plt.xlabel("Change in Number of Districts")
plt.ylabel("Number of Counties")
plt.tight_layout()

# %%
colors = ["#C38D8D", "#A7B1C2", "#4C72B0", "#4C72B0"]

ax = analysis_df["delta_districts"].value_counts().sort_index().plot(kind="bar",figsize=(6,5),color=colors)
ax.set_title("Congressional Boundary Changes Distributed Across Counties")
ax.set_xlabel("Net Change in Congressional Districts Touching a County")
ax.set_xticklabels(["1 Fewer", "No Change", " 1 More", "2 More"], rotation=0)
ax.set_ylabel("Number of Counties")
plt.tight_layout()

# %% [markdown]
# Change in CD Fragmentation by County

# %%
frag_map = counties_geom.merge(fragmentation[["COUNTYFP", "delta_districts"]], on="COUNTYFP", how="left")

# %%
fig, ax = plt.subplots(figsize=(8, 8))
frag_map.plot(column="delta_districts",cmap="coolwarm",legend=True,ax=ax,legend_kwds={"shrink": 0.6})
ax.set_title("Change in Congressional District Fragmentation by County")
ax.axis("off")
# Out:
# (-90.74346789999998, -81.2137301, 34.8982147, 36.7628753)

# %%
fig, ax = plt.subplots(figsize=(10, 4))
frag_map.plot(column="delta_districts",
              cmap="RdBu_r",
              linewidth=0.2,
              edgecolor="white",
              legend=True,
              ax=ax,
              vmin=-1,
              vmax=2)
ax.set_title("Where Congressional Boundary Changes Occurred")
ax.axis("off")
# Out:
# (-90.74346789999998, -81.2137301, 34.8982147, 36.7628753)

# %% [markdown]
# Scatterplot Delta Districts vs Margin

# %%
margin_wide = (analysis_df.pivot(index="COUNTYFP", columns="year", values="margin_votes").reset_index())
margin_wide["delta_margin"] = margin_wide[2022] - margin_wide[2018]

# %%
margin_wide[["COUNTYFP", 2018, 2022, "delta_margin"]].head()
# Out:
# year COUNTYFP     2018     2022  delta_margin
# 0         001   6803.0   7171.0         368.0
# 1         003   6042.0   6465.0         423.0
# 2         005   2097.0   2491.0         394.0
# 3         007   2179.0   2515.0         336.0
# 4         009  19596.0  20154.0         558.0

# %%
scatter_df = margin_wide.merge(fragmentation[["COUNTYFP", "delta_districts"]], on="COUNTYFP", how="left")

# %%
scatter_df["delta_districts"].isna().sum()
# Out:
# 0

# %%
sns.scatterplot(data=scatter_df.dropna(subset=["delta_districts", "delta_margin"]), x="delta_districts",y="delta_margin")
plt.title("Change in District Fragmentation vs Change in Voting Margin (2018 → 2022)")
plt.xlabel("Change in Number of Districts per County")
plt.ylabel("Change in Margin of Victory (Votes)")
plt.xticks(ticks=sorted(scatter_df["delta_districts"].dropna().unique()))
plt.tight_layout()

# %%
sns.scatterplot(data=scatter_df.dropna(subset=["delta_districts", "delta_margin"]),x="delta_districts",y="delta_margin")
plt.title("Change in District Fragmentation vs Change in Voting Margin (2018 → 2022)")
plt.xlabel("Change in Number of Districts per County")
plt.ylabel("Change in Margin of Victory (Votes)")
plt.xticks(ticks=sorted(scatter_df["delta_districts"].dropna().unique()))

lower = scatter_df["delta_margin"].quantile(0.05)
upper = scatter_df["delta_margin"].quantile(0.95)
plt.ylim(lower, upper)

plt.tight_layout()

# %%
plt.figure(figsize=(7,5))
plt.scatter(scatter_df["delta_districts"],scatter_df["delta_margin"],s=35,alpha=0.65)
plt.axhline(0, linestyle="--", linewidth=1, alpha=0.6)

plt.title("How Boundary Changes Relate to Shifts in Election Margins")
plt.xlabel("Net Change in Congressional Districts Touching a County")
plt.ylabel("Change in Margin of Victory (Votes)")
plt.xticks(sorted(scatter_df["delta_districts"].unique()))
xticks = sorted(scatter_df["delta_districts"].unique())
plt.xticks( [-1, 0, 1], ["Fewer", "No Change", "More"])

lower = scatter_df["delta_margin"].quantile(0.05)
upper = scatter_df["delta_margin"].quantile(0.95)
plt.ylim(lower, upper)
plt.tight_layout()

# %% [markdown]
# Box Plot - Change in Margin

# %%
scatter_df["fragmented"] = scatter_df["delta_districts"] != 0

# %%
sns.boxplot(data=scatter_df.dropna(subset=["fragmented", "delta_margin"]), x="fragmented", y="delta_margin")
plt.title("Change in Voting Margin (2018→2022): Fragmented vs Non-Fragmented Counties")
plt.xlabel("County Experienced District Fragmentation Change")
plt.ylabel("Change in Margin of Victory (Votes)")
plt.xticks([0, 1], ["No Change", "Changed"])
lower = scatter_df["delta_margin"].quantile(0.05)
upper = scatter_df["delta_margin"].quantile(0.95)
plt.ylim(lower, upper)
plt.tight_layout()

# %%
plot_df = scatter_df.dropna(subset=["fragmented", "delta_margin"])
plt.figure(figsize=(8, 6))
sns.boxplot(data=plot_df,x="fragmented",y="delta_margin",palette=["#BFC7D5", "#6E8FB5"],showfliers=True,
            flierprops=dict(marker='o', markersize=4, alpha=0.4))

plt.title("Shift of Election Margins in Counties With and Without Boundary Changes",fontsize=12)
plt.xlabel("County Redistricting Status", fontsize=10)
plt.ylabel("Change in Election Margin (Votes)", fontsize=10)
plt.xticks([0, 1], ["No Boundary Change", "Boundary Change"])

lower = plot_df["delta_margin"].quantile(0.05)
upper = plot_df["delta_margin"].quantile(0.95)
plt.ylim(lower, upper)

plt.tight_layout()
plt.show()
# Out:
# C:\Users\kanak\AppData\Local\Temp\ipykernel_9068\971930074.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=plot_df,x="fragmented",y="delta_margin",palette=["#BFC7D5", "#6E8FB5"],showfliers=True,

# %% [markdown]
# Box Plot - Change in Voter Turnout

# %%
turnout_wide = (analysis_df.pivot(index="COUNTYFP", columns="year", values="total_votes").reset_index())
turnout_wide["delta_turnout"] = turnout_wide[2022] - turnout_wide[2018]

# %%
turnout_df = turnout_wide.merge(fragmentation[["COUNTYFP", "delta_districts"]], on="COUNTYFP", how="left")
turnout_df["fragmented"] = turnout_df["delta_districts"] != 0

# %%
sns.boxplot(data=turnout_df.dropna(subset=["fragmented", "delta_turnout"]), x="fragmented", y="delta_turnout")
plt.title("Change in Turnout (2018→2022): Fragmented vs Non-Fragmented Counties")
plt.xlabel("County Experienced District Fragmentation Change")
plt.ylabel("Change in Total Votes Cast")
plt.xticks([0, 1], ["No Change", "Changed"])
plt.tight_layout()

# %%
sns.boxplot(data=turnout_df.dropna(subset=["fragmented", "delta_turnout"]), x="fragmented", y="delta_turnout")
plt.title("Change in Turnout (2018→2022): Fragmented vs Non-Fragmented Counties")
plt.xlabel("County Experienced District Fragmentation Change")
plt.ylabel("Change in Total Votes Cast")
plt.xticks([0, 1], ["No Change", "Changed"])
lower = turnout_df["delta_turnout"].quantile(0.05)
upper = turnout_df["delta_turnout"].quantile(0.95)
plt.ylim(lower, upper)
plt.tight_layout()

# %%
turnout_wide["pct_change_turnout"] = ((turnout_wide[2022] - turnout_wide[2018]) / turnout_wide[2018]) * 100

# %%
turnout_df = turnout_wide.merge(fragmentation[["COUNTYFP", "delta_districts"]], on="COUNTYFP", how="left")
turnout_df["fragmented"] = turnout_df["delta_districts"] != 0

# %%
sns.boxplot(data=turnout_df.dropna(subset=["fragmented", "pct_change_turnout"]),x="fragmented",y="pct_change_turnout")
plt.title("Percent Change in Turnout (2018→2022): Fragmented vs Non-Fragmented Counties")
plt.xlabel("County Experienced District Fragmentation Change")
plt.ylabel("Percent Change in Total Votes")
plt.xticks([0, 1], ["No Change", "Changed"])
plt.tight_layout()

# %%
plot_df = turnout_df.dropna(subset=["fragmented", "pct_change_turnout"])

plt.figure(figsize=(8, 6))
sns.boxplot(data=plot_df,x="fragmented",y="pct_change_turnout",order=[False, True],palette=["#c9d1d9", "#7f96ad"],linewidth=1.2,fliersize=4)
plt.title("How Boundary Changes Relate to Changes in Voter Turnout",fontsize=13,pad=12)
plt.xlabel("County Redistricting Status")
plt.ylabel("Percent Change in Turnout (%)")
plt.xticks([0, 1], ["No Boundary Change", "Boundary Changed"])

plt.tight_layout()
plt.show()
# Out:
# C:\Users\kanak\AppData\Local\Temp\ipykernel_9068\950817549.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=plot_df,x="fragmented",y="pct_change_turnout",order=[False, True],palette=["#c9d1d9", "#7f96ad"],linewidth=1.2,fliersize=4)

# %% [markdown]
# Bar - Summary Stats: Avg Change in Voting Margin & Turnout

# %%
summary_df = scatter_df.merge(turnout_df[["COUNTYFP", "pct_change_turnout"]],on="COUNTYFP",how="left")
summary_stats = summary_df.groupby("fragmented").agg(
    avg_delta_margin=("delta_margin", "mean"), 
    avg_pct_turnout_change=("pct_change_turnout", "mean")).reset_index()

# %%
summary_stats
# Out:
#    fragmented  avg_delta_margin  avg_pct_turnout_change
# 0       False       -370.517647              -19.462274
# 1        True      -2191.100000              -20.239710

# %%
plt.bar(summary_stats["fragmented"].astype(str), summary_stats["avg_delta_margin"])
plt.title("Average Change in Voting Margin by Redistricting Exposure")
plt.xlabel("County Experienced District Fragmentation Change")
plt.ylabel("Average Change in Margin (Votes)")
plt.xticks(["False", "True"], ["No Change", "Changed"])
plt.tight_layout()

# %%
fig, ax = plt.subplots()
ax.bar(["No Change", "Changed"], summary_stats["avg_delta_margin"])
ax.axhline(0, linewidth=1)  
m = max(abs(summary_stats["avg_delta_margin"].min()), abs(summary_stats["avg_delta_margin"].max()))
plt.ylim(-m*1.1, m*1.1)
ax.set_title("Average Change in Voting Margin by Redistricting Exposure")
ax.set_xlabel("County Experienced District Fragmentation Change")
ax.set_ylabel("Average Change in Margin (Votes)")
plt.tight_layout()

# %%
fig, ax = plt.subplots()
labels = ["No Boundary Change", "Boundary Changed"]
values = summary_stats["avg_delta_margin"].values
colors = ["#c9d1d9", "#7f96ad"]

ax.bar(labels, values, color=colors)
ax.axhline(0, color="gray", linewidth=1, linestyle="--")
m = max(abs(values.min()), abs(values.max()))
ax.set_ylim(-m*1.1, m*1.1)

ax.set_title("Avg Shift in Election Margin by Redistricting Exposure", pad=12)
ax.set_xlabel("County Redistricting Status")
ax.set_ylabel("Avg Shift in Margin of Victory (Votes)")

for i, v in enumerate(values):
    ax.text(i, v + (m*0.03 if v >= 0 else -m*0.05), f"{v:,.0f}", ha="center", va="center", fontsize=10)

plt.tight_layout()
plt.show()

# %%
plt.bar(summary_stats["fragmented"].astype(str), summary_stats["avg_pct_turnout_change"])
plt.title("Average Percent Change in Turnout by Redistricting Exposure")
plt.xlabel("County Experienced District Fragmentation Change")
plt.ylabel("Average Percent Change in Turnout")
plt.xticks(["False", "True"], ["No Change", "Changed"])
plt.tight_layout()

# %%
fig, ax = plt.subplots()
ax.bar(["No Change", "Changed"], summary_stats["avg_pct_turnout_change"])
ax.axhline(0, linewidth=1)
m = max(abs(summary_stats["avg_pct_turnout_change"].min()), abs(summary_stats["avg_pct_turnout_change"].max()))
plt.ylim(-m*1.1, m*1.1)
ax.set_title("Average Percent Change in Turnout by Redistricting Exposure")
ax.set_xlabel("County Experienced District Fragmentation Change")
ax.set_ylabel("Average Percent Change in Turnout")
plt.tight_layout()

# %%
fig, ax = plt.subplots()
labels = ["No Boundary Change", "Boundary Changed"]
values = summary_stats["avg_pct_turnout_change"].values
colors = ["#c9d1d9", "#7f96ad"]

ax.bar(labels, values, color=colors)
ax.axhline(0, color="gray", linewidth=1, linestyle="--")
m = max(abs(values.min()), abs(values.max()))
ax.set_ylim(-m*1.1, m*1.1)

ax.set_title("Avg Turnout Change by Redistricting Exposure", pad=12)
ax.set_xlabel("County Redistricting Status")
ax.set_ylabel("Avg Turnout Change (%)")

for i, v in enumerate(values):
    ax.text(i, v + (m*0.03 if v >= 0 else -m*0.05), f"{v:.1f}%", ha="center", va="center", fontsize=10)

plt.tight_layout()
plt.show()

# %% [markdown]
# Scatter/Bubble - Are the biggest counties driving the relationship between county turnout and fragmentation?

# %%
sns.scatterplot(data=scatter_df.merge(turnout_wide[["COUNTYFP", 2018]], on="COUNTYFP"), x="delta_districts",y="delta_margin", size=2018,
                hue="fragmented",sizes=(20, 400),alpha=0.6)
lower = scatter_df["delta_margin"].quantile(0.05)
upper = scatter_df["delta_margin"].quantile(0.95)
plt.ylim(lower, upper)
plt.title("Fragmentation vs Margin Change, Weighted by County Turnout")
plt.tight_layout()

# %%
turnout_for_merge = turnout_wide.copy()
turnout_for_merge.columns.name = None

# %%
turnout_for_merge = turnout_for_merge.rename(columns={2018: "turnout_2018"})

# %%
assert "turnout_2018" in turnout_for_merge.columns

# %%
import numpy as np

# %%
plot_df = scatter_df.merge(turnout_for_merge[["COUNTYFP", "turnout_2018"]],on="COUNTYFP",how="left").copy()
plot_df["boundary_changed"] = plot_df["delta_districts"] != 0
plot_df["turnout_size"] = np.log1p(plot_df["turnout_2018"])

# %%
from matplotlib.lines import Line2D

turnout_lookup = turnout_wide[["COUNTYFP", 2018]].copy()
turnout_lookup = turnout_lookup.rename(columns={2018: "turnout_2018"})

plot_df = scatter_df.merge(turnout_lookup, on="COUNTYFP", how="left").copy()

plot_df["turnout_2018"] = plot_df["turnout_2018"].fillna(0)

plot_df["boundary_changed"] = plot_df["delta_districts"] != 0
plot_df["status"] = np.where(plot_df["boundary_changed"], "Boundary Changed", "No Boundary Change")

plot_df["turnout_size"] = np.log1p(plot_df["turnout_2018"])

plot_df = plot_df.dropna(subset=["delta_margin", "delta_districts"])

lower = plot_df["delta_margin"].quantile(0.05)
upper = plot_df["delta_margin"].quantile(0.95)

plt.figure(figsize=(8, 7))
ax = sns.scatterplot(data=plot_df,x="delta_districts",y="delta_margin",hue="status",size="turnout_size",sizes=(60, 700),alpha=0.6,linewidth=0,
                     legend=False)

ax.axhline(0, linestyle="--", linewidth=1, color="gray")

ax.set_xlim(-1.2, 1.2)
ax.set_xticks([-1, 0, 1])
ax.set_xticklabels(["Fewer Districts", "No Change", "More Districts"])

ax.set_ylim(lower, upper)

ax.set_title("Turnout-Weighted Relationship Between Boundary Change and Margin Shift (2018–2022)")
ax.set_xlabel("Net Change in Congressional Districts Touching a County")
ax.set_ylabel("Change in Margin of Victory (Votes)")

palette = sns.color_palette()
status_order = ["No Boundary Change", "Boundary Changed"]


unique_statuses = list(plot_df["status"].unique())

plt.cla()
custom_palette = {"No Boundary Change": "#4C78A8",  
                  "Boundary Changed":   "#C38D8D"}

ax = sns.scatterplot(data=plot_df,x="delta_districts",y="delta_margin",hue="status",hue_order=status_order,palette=custom_palette,size="turnout_size",
                     sizes=(60, 700),alpha=0.6,linewidth=0,legend=False)

ax.axhline(0, linestyle="--", linewidth=1, color="gray")
ax.set_xlim(-1.2, 1.2)
ax.set_xticks([-1, 0, 1])
ax.set_xticklabels(["Fewer Districts", "No Change", "More Districts"])
ax.set_ylim(lower, upper)

ax.set_title("Turnout-Weighted Relationship Between Boundary Change and Margin Shift (2018–2022)")
ax.set_xlabel("Net Change in Congressional Districts Touching a County")
ax.set_ylabel("Change in Margin of Victory (Votes)")

legend_elements = [Line2D([0], [0], marker='o', color='w', label='No Boundary Change',
                    markerfacecolor=custom_palette["No Boundary Change"], markersize=10),
                   Line2D([0], [0], marker='o', color='w', label='Boundary Changed',
                    markerfacecolor=custom_palette["Boundary Changed"], markersize=10),]
ax.legend(handles=legend_elements, title="County Redistricting Status", loc="upper left")

ax.text(0.99, 0.02, "Bubble size ∝ 2018 County Turnout", transform=ax.transAxes, ha="right", va="bottom", fontsize=10)

plt.tight_layout()
plt.show()

# %%
[c for c in plot_df.columns if "2018" in str(c)]
# Out:
# [2018, 'turnout_2018']

# %% [markdown]
# Box Plot - Do fragmented counties experience greater electoral volatility?

# %%
scatter_df["abs_delta_margin"] = scatter_df["delta_margin"].abs()

# %%
sns.boxplot(
    data=scatter_df,
    x="fragmented",
    y="abs_delta_margin"
)
plt.title("Magnitude of Margin Change by Redistricting Exposure")
plt.ylabel("Absolute Change in Margin (Votes)")
plt.xticks([0,1],["No Change","Changed"])
plt.tight_layout()

# %%
fig, ax = plt.subplots(figsize=(8, 6))
sns.boxplot(data=scatter_df.dropna(subset=["fragmented", "abs_delta_margin"]),x="fragmented",y="abs_delta_margin",ax=ax)
ax.set_title("Magnitude of Margin Change by Redistricting Exposure")
ax.set_xlabel("County Experienced District Fragmentation Change")
ax.set_ylabel("Absolute Change in Margin (Votes)")
ax.set_xticklabels(["No Change", "Changed"])
upper = scatter_df["abs_delta_margin"].quantile(0.95)
ax.set_ylim(0, upper)
plt.tight_layout()
# Out:
# C:\Users\kanak\AppData\Local\Temp\ipykernel_9068\687057134.py:6: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(["No Change", "Changed"])

# %%
plot_df = scatter_df.dropna(subset=["fragmented", "delta_margin"]).copy()
plot_df["abs_delta_margin"] = plot_df["delta_margin"].abs()
plot_df["status"] = plot_df["fragmented"].map({False: "No Boundary Change",True: "Boundary Changed"})

plt.figure(figsize=(10, 7))
ax = sns.boxplot(data=plot_df,x="status",y="abs_delta_margin",palette=["#BFC7D5", "#6E8FB5"],width=0.55,medianprops={"color": "black", "linewidth": 2})
ax.set_title("Larger Electoral Swings in Counties Affected by Redistricting (2018–2022)")
ax.set_xlabel("County Redistricting Status")
ax.set_ylabel("Absolute Change in Margin of Victory (Votes)")

cap = plot_df["abs_delta_margin"].quantile(0.95)
ax.set_ylim(0, cap)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\kanak\AppData\Local\Temp\ipykernel_9068\2319413813.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.boxplot(data=plot_df,x="status",y="abs_delta_margin",palette=["#BFC7D5", "#6E8FB5"],width=0.55,medianprops={"color": "black", "linewidth": 2})

# %% [markdown]
# Pie - Share of Counties by Fragmentation Type

# %%
fragmentation["delta_districts"].value_counts(normalize=True).plot(kind="pie", autopct="%.1f%%")
plt.title("Share of Counties by Change in District Fragmentation")
plt.ylabel("")
# Out:
# Text(0, 0.5, '')

# %%
labels_map = {-1: "Less fragmented",
              0: "No change",
              1: "Fragmented",
              2: "More fragmented"}

counts = fragmentation["delta_districts"].value_counts().sort_index()
labels = [labels_map[i] for i in counts.index]
plt.figure(figsize=(7,7))
plt.pie(counts, labels=labels, autopct="%.1f%%", startangle=90)
plt.title("Share of Counties by Change in District Fragmentation")
plt.tight_layout()

# %% [markdown]
# Change in Voting Margin by County

# %%
delta_map = counties_geom.merge(scatter_df[["COUNTYFP", "delta_margin"]],on="COUNTYFP")
delta_map.plot(column="delta_margin", cmap="RdBu", legend=True, legend_kwds={"shrink":0.6},figsize=(8,8))
plt.title("Change in Voting Margin by County (2018→2022)")
plt.axis("off")
# Out:
# (-90.74346789999998, -81.2137301, 34.8982147, 36.7628753)

# %%
import matplotlib.colors as colors

vmax = max(abs(delta_map["delta_margin"].min()), abs(delta_map["delta_margin"].max()))
norm = colors.TwoSlopeNorm(vmin=-vmax, vcenter=0, vmax=vmax)

delta_map.plot(column="delta_margin",cmap="RdBu",linewidth=0.3,edgecolor="white",norm=norm,legend=True, figsize=(10, 3))
# Out:
# <Axes: >

# %%
fig, ax = plt.subplots(figsize=(10, 3))
delta_map.plot(column="delta_margin",cmap="Blues_r",linewidth=0.3,edgecolor="white",legend=True,ax=ax)

ax.set_title("Change in Voting Margin by County (2018–2022)", fontsize=14)
ax.axis("off")
plt.tight_layout()
plt.show()

# %%
delta_map["abs_delta_margin"] = delta_map["delta_margin"].abs()

fig, ax = plt.subplots(figsize=(10, 3))
delta_map.plot(column="abs_delta_margin",cmap="Blues",linewidth=0.3,edgecolor="white",legend=True,ax=ax)

ax.set_title("Magnitude of Change in Voting Margin by County (2018–2022)", fontsize=14)
ax.axis("off")
plt.tight_layout()
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10,3))
df = delta_map.copy()
df["abs_delta_margin"] = df["delta_margin"].abs()

vmin = 0
vmax = df["abs_delta_margin"].quantile(0.98)

df.plot(column="abs_delta_margin",cmap="Blues",vmin=vmin,vmax=vmax,linewidth=0.3,edgecolor="white",legend=True,ax=ax)

ax.set_title("Magnitude of Change in Voting Margin by County (2018–2022)")
ax.axis("off")
plt.tight_layout()
plt.show()
